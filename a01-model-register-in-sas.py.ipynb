# %% [markdown]
# # a01. Model Register in SAS
# ## How does a Model Developer Register Models to the Central Model Repository
#
# ---
#
# ## Table of Content
# 1. [訓練模型](#1.-訓練模型)<br>
# 2. [註冊模型](#2.-註冊模型)<br>
# 2-1. 新增連線<br>
# 2-2. 新增模型專案<br>
# 2-3. 更新模型專案的屬性<br>
# 2-4. 新增模型<br>
# 2-5. 新增模型檔案<br>
# 2-6. 新增模型的套件需求<br>
# 2-7. 簡易註冊模型 (Optional)<br>
# 3. [模型版本控制](#3.-模型版本控制)<br>
# 3-1. 新增模型的版本號碼<br>
# 3-2. 更新模型的屬性<br>
# 3-3. 確認模型的最新版本和屬性<br>
#
#
#
# ## Reference
# 1. [Python sasctl Package - Overview](https://github.com/sassoftware/python-sasctl)
# 2. [Python sasctl Package - User Guide](https://sassoftware.github.io/python-sasctl/index.html)
# 3. [SAS Model Manager - REST APIs](https://developer.sas.com/apis/rest/DecisionManagement/)
# 4. [SAS Model Manager - REST APIs Examples](https://github.com/sassoftware/devsascom-rest-api-samples/tree/master/DecisionManagement)

# %% [markdown]
# ---
# # 1. 訓練模型
# [Top](#Table-of-Content)

# %%
import pandas as pd
import pickle
import os
import sys
from datetime import datetime
from pprint import pprint

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
# %%time

column_type = {'LOAN':'float32', 'MORTDUE':'float32', 'VALUE':'float32', 'YOJ':'float32', 'DEROG':'float32', 
               'DELINQ':'float32', 'CLAGE':'float32', 'NINQ':'float32', 'CLNO':'float32', 'DEBTINC':'float32'}

data = pd.read_csv('https://support.sas.com/documentation/onlinedoc/viya/exampledatasets/hmeq.csv', dtype = column_type)

del data["REASON"]
del data["JOB"]

y = data['BAD']
X = data.iloc[:,1:]
X = X.fillna(0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 2021)

model_dt = tree.DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
# Out:
# Wall time: 3.01 s
# DecisionTreeClassifier()

# %% [markdown]
# ### <font color='blue'>學員操作</font>

# %%
model_gb = GradientBoostingClassifier()
model_gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ---
# # 2. 註冊模型
# [Top](#Table-of-Content)

# %% [markdown]
# ### 2-1. 新增連線 (Connecting to SAS MM)

# %%
#SAS API
import sasctl
from sasctl import Session, register_model
from sasctl.services import folders, files, model_repository, projects

sas_session = Session('10.249.6.39', 'modelDeveloper', 'demopw', verify_ssl = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.249.6.39'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ### 2-2. 新增模型專案

# %%
myProject_name = 'hmeq_project'

myRepository = model_repository.get_repository("Public")

input_variable_dict = [{'name': v, 'role': 'input', 'type': 'decimal', 'length': 8} for v in X.columns]
output_variable_dict = [{'name':'BAD', 'role':'output', 'type':'binary', 'length': 2, 'description': 'Put your comments here.'}]
# The role of the variable. Valid values are: input, output
# The type of variable. Valid values are: boolean, character, date, datetime, decimal, integer, binary, varying-length binary
# The measurement level of the variable. Valid values are: binary, interval, nominal, ordinal

if not model_repository.list_projects(filter= f'eq(name, {myProject_name})'):
    myProject = model_repository.create_project(
        project = {
            'name': myProject_name,
            'description': 'to demostrate management on Python models in SAS MM',
            'function': 'Classification',
            'variables': input_variable_dict + output_variable_dict
        },
        repository = myRepository
    )  

# 顯示模型專案的所有屬性
pprint(myProject)
# Out:
# {'candidateChampionHonored': False,
#  'challengerModels': [],
#  'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:21:11.921Z',
#  'description': 'to demostrate management on Python models in SAS MM',
#  'folderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'function': 'Classification',
#  'globalTags': [],
#  'id': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#  'latestVersion': 'Version 1',
#  'links': [{'href': '/modelRepository/projects',
#             'itemType': 'application/vnd.sas.models.project.summary',
#             'method': 'GET',
#             'rel': 'up',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.project',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#             'method': 'GET',
#             'rel': 'alternate',
#             'type': 'application/vnd.sas.models.project.summary',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.project',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/projectVersions',
#             'itemType': 'application/vnd.sas.models.project.version',
#             'method': 'GET',
#             'rel': 'projectVersions',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/projectVersions'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/models',
#             'itemType': 'application/vnd.sas.models.model.summary',
#             'method': 'GET',
#             'rel': 'projectModels',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/models'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables',
#             'itemType': 'application/vnd.sas.models.variable.summary',
#             'method': 'GET',
#             'rel': 'projectVariables',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/history',
#             'method': 'GET',
#             'rel': 'projectHistory',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/history'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion',
#             'method': 'GET',
#             'rel': 'championModel',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion',
#             'method': 'DELETE',
#             'rel': 'unsetChampion',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code',
#             'method': 'GET',
#             'rel': 'championScoreCodeJson',
#             'type': 'text/vnd.sas.models.score.code.raw',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code',
#             'method': 'GET',
#             'rel': 'championScoreCodeText',
#             'type': 'text/plain',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code',
#             'method': 'GET',
#             'rel': 'championDs2packageScoreCode',
#             'type': 'text/vnd.sas.models.score.code.ds2package',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code',
#             'method': 'GET',
#             'rel': 'championDs2ScoreCode',
#             'type': 'text/vnd.sas.models.score.code.ds2',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion/code'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers',
#             'itemType': 'application/vnd.sas.models.model.summary',
#             'method': 'GET',
#             'rel': 'challengers',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers',
#             'method': 'DELETE',
#             'rel': 'unsetChallengers',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/contents',
#             'method': 'GET',
#             'rel': 'getProjectFiles',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/contents'}],
#  'location': '/Model Repositories/Public',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:21:12.038Z',
#  'name': 'hmeq_project',
#  'repositoryId': 'e85658ee-ee07-4e91-bd09-e50edb520097',
#  'tags': [],
#  'targetLevel': '',
#  'variables': [{'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '1afbc62c-b97b-4e89-8923-aaf407cd2876',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/1afbc62c-b97b-4e89-8923-aaf407cd2876'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'LOAN',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': 'e1522f4b-d9a6-4530-9b9b-3ca2128452c7',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e1522f4b-d9a6-4530-9b9b-3ca2128452c7'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'MORTDUE',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '3fc1269d-27d6-4166-8dca-2b13aa97ffa7',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/3fc1269d-27d6-4166-8dca-2b13aa97ffa7'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'VALUE',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/6d037d65-1eaf-4cd4-acd9-e9595c3cd6bf'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'YOJ',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '027fbfcb-96bc-4446-87a2-665c8b4bd9ca',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/027fbfcb-96bc-4446-87a2-665c8b4bd9ca'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'DEROG',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': 'b7919e27-a751-498b-b931-195d5b913d72',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/b7919e27-a751-498b-b931-195d5b913d72'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'DELINQ',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '2568e743-96ef-47b7-b1b7-92a96facae0c',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/2568e743-96ef-47b7-b1b7-92a96facae0c'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'CLAGE',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '98160d11-31c6-4d92-942a-55da9e89c537',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/98160d11-31c6-4d92-942a-55da9e89c537'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'NINQ',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': 'e8f1c625-9337-4f03-808b-c8583b1ae5d0',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/e8f1c625-9337-4f03-808b-c8583b1ae5d0'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'CLNO',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'id': '52a14b56-bd3d-4098-bb19-eff81b49a678',
#                 'length': 8,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/52a14b56-bd3d-4098-bb19-eff81b49a678'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'DEBTINC',
#                 'role': 'input',
#                 'type': 'decimal',
#                 'version': 2},
#                {'createdBy': 'modelDeveloper',
#                 'creationTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'description': 'Put your comments here.',
#                 'id': '5848847f-1420-4c69-ad16-95caf2481776',
#                 'length': 2,
#                 'links': [{'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776',
#                            'itemType': 'application/vnd.sas.models.variable',
#                            'method': 'GET',
#                            'rel': 'up',
#                            'type': 'application/vnd.sas.collection',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776',
#                            'method': 'GET',
#                            'rel': 'self',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776',
#                            'method': 'PUT',
#                            'rel': 'update',
#                            'type': 'application/vnd.sas.models.variable',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776'},
#                           {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776',
#                            'method': 'DELETE',
#                            'rel': 'delete',
#                            'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/variables/5848847f-1420-4c69-ad16-95caf2481776'}],
#                 'modifiedBy': 'modelDeveloper',
#                 'modifiedTimeStamp': '2021-03-05T06:21:12.028Z',
#                 'name': 'BAD',
#                 'role': 'output',
#                 'type': 'binary',
#                 'version': 2}],
#  'version': 2}

# %%
print(f'My project ID: \033[94m{myProject.get("id")}\033[0;0m')
# Out:
# My project ID: 8373e5fc-ca71-4841-af2e-f77bdeca6ea5

# %% [markdown]
# ### 2-3. 更新模型專案的屬性

# %%
print(f'Target Variable: \033[94m{myProject.get("targetVariable")}\033[0;0m')
print(f'Class Target Values: \033[94m{myProject.get("classTargetValues")}\033[0;0m')
print(f'Target Event Value: \033[94m{myProject.get("targetEventValue")}\033[0;0m')
# Out:
# Target Variable: None
# Class Target Values: None
# Target Event Value: None

# %%
myProject['targetVariable'] = 'bad'
myProject['classTargetValues'] = 'bad,good'
myProject['targetEventValue'] = 'bad'

model_repository.update_project(myProject)

print(f'Target Variable: \033[94m{myProject.get("targetVariable")}\033[0;0m')
print(f'Class Target Values: \033[94m{myProject.get("classTargetValues")}\033[0;0m')
print(f'Target Event Value: \033[94m{myProject.get("targetEventValue")}\033[0;0m')
# Out:
# Target Variable: bad
# Class Target Values: bad,good
# Target Event Value: bad

# %% [markdown]
# ### 2-4. 新增模型

# %%
myModel_name = 'Sklearn Decision Tree'

myModel_1 = model_repository.create_model(
    project = myProject,
    
    model = {
        'name': myModel_name,
        'trainCodeType': 'Python',
        'scoreCodeType': 'Python'
    },
    modeler = 'frank',    
    description = 'Manually create model artifacts',
    
    function = "Classification",
    algorithm = 'Decision Tree',
    tool = f'Python {sys.version_info.major}',
    is_challenger = True,
    
    input_variables = input_variable_dict,
    output_variables = output_variable_dict,
    
    properties = {
        'gitlab-access-token': 'ynJH8ppLyiB_2L5sT2NY',
        'gitlab-project-id': '24272994',
        'author_email': 'fkl@sas.com',
        'author_name': 'fkl'  
    }
)

# 顯示模型的所有屬性
pprint(myModel_1)
# Out:
# {'algorithm': 'Decision Tree',
#  'candidateChampion': False,
#  'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:07.277Z',
#  'description': 'Manually create model artifacts',
#  'folderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'function': 'Classification',
#  'globalTags': [],
#  'id': '4c9e48c6-83fe-496c-9acd-692576f48b29',
#  'immutable': False,
#  'indirectFolderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'inputVariables': [{'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'db133fab-9f61-407e-b9f1-d7938d94bf84',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'LOAN',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'MORTDUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'VALUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'd142dea5-5fc2-44e3-a748-9c6570d59603',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'YOJ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DEROG',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '639f61dc-f720-4e71-b395-5965353cfa30',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DELINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'd7578afd-1619-4731-af8a-4182b94c97f0',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'CLAGE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'NINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'CLNO',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DEBTINC',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2}],
#  'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'GET',
#             'rel': 'alternate',
#             'type': 'application/vnd.sas.models.model.summary',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents',
#             'method': 'GET',
#             'rel': 'contents',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents'}],
#  'location': '/Model Repositories/Public',
#  'modelVersionName': '1.0',
#  'modelVersions': [],
#  'modeler': 'frank',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:22:07.277Z',
#  'name': 'Sklearn Decision Tree',
#  'outputVariables': [{'createdBy': 'modelDeveloper',
#                       'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                       'description': 'Put your comments here.',
#                       'id': 'f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                       'length': 2,
#                       'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'itemType': 'application/vnd.sas.models.variable',
#                                  'method': 'GET',
#                                  'rel': 'up',
#                                  'type': 'application/vnd.sas.collection',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'GET',
#                                  'rel': 'self',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'PUT',
#                                  'rel': 'update',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'DELETE',
#                                  'rel': 'delete',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'}],
#                       'modifiedBy': 'modelDeveloper',
#                       'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                       'name': 'BAD',
#                       'role': 'output',
#                       'type': 'binary',
#                       'version': 2}],
#  'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#  'projectName': 'hmeq_project',
#  'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#  'projectVersionName': 'Version 1',
#  'projectVersionNum': '1.0',
#  'properties': [{'name': 'gitlab-access-token',
#                  'type': 'string',
#                  'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                 {'name': 'gitlab-project-id',
#                  'type': 'string',
#                  'value': '24272994'},
#                 {'name': 'author_email',
#                  'type': 'string',
#                  'value': 'fkl@sas.com'},
#                 {'name': 'author_name', 'type': 'string', 'value': 'fkl'}],
#  'repositoryId': 'e85658ee-ee07-4e91-bd09-e50edb520097',
#  'retrainable': False,
#  'role': 'challenger',
#  'scoreCodeType': 'Python',
#  'suggestedChampion': False,
#  'tags': [],
#  'tool': 'Python 3',
#  'trainCodeType': 'Python',
#  'version': 2}

# %%
print(f'Sklearn Decision Tree model ID: \033[94m{myModel_1.get("id")}\033[0;0m')
# Out:
# Sklearn Decision Tree model ID: 4c9e48c6-83fe-496c-9acd-692576f48b29

# %% [markdown]
# ### 2-5. 新增模型檔案 (以.pkl檔案為例)

# %%
with open('./model_dt.pkl', 'wb') as file:
    pickle.dump(model_dt, file)
    
myModel_pkl = open('./model_dt.pkl', 'rb')



myModelFile_1 = model_repository.add_model_content(
    model = myModel_1,
    file = myModel_pkl,
    name = 'model_dt.pkl',
    role = 'Python pickle'
)

# 顯示模型Pickle檔案的所有屬性
pprint(myModelFile_1)
# Out:
# {'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:11.352Z',
#  'fileUri': '/files/files/a3286458-7988-4de6-8f2c-8cc99fb650ad',
#  'id': '57cd7ac4-f6a0-4e7d-92a0-d7d246f52557',
#  'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model.file',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.model.file',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557/content',
#             'method': 'GET',
#             'rel': 'content',
#             'type': 'application/octet-stream',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/57cd7ac4-f6a0-4e7d-92a0-d7d246f52557/content'}],
#  'modelId': '4c9e48c6-83fe-496c-9acd-692576f48b29',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:22:11.352Z',
#  'name': 'model_dt.pkl',
#  'role': 'Python pickle',
#  'version': 2}

# %%
print(f'model_dt.pkl file\'s content ID: {myModelFile_1.get("id")}')

# %% [markdown]
# ### 2-6. 新增模型的套件需求

# %%
import pkg_resources

working_set = pkg_resources.working_set
list_package = sorted(['%s==%s' % (i.key, i.version) for i in working_set])

list_package_df = pd.DataFrame(list_package, columns = ['package'])
list_package_df.to_csv(f'./requirements.txt', index = False, header = False)

requirements_txt = open(f'./requirements.txt', 'r')

# os.system('powershell.exe pip freeze > ./requirements.txt')
# requirements_txt = open('./requirements.txt', 'r')       


myModelFile_2 = model_repository.add_model_content(
    model = myModel_1, 
    file = requirements_txt, 
    name = 'requirements.txt', 
    role = 'Requirements'
)

# 顯示該檔案的所有屬性
pprint(myModelFile_2)
# Out:
# {'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:15.680Z',
#  'fileUri': '/files/files/0ce76f51-7008-469e-a04f-f03abf20cec7',
#  'id': 'a4667441-94ef-43c3-8b2f-0819851d6058',
#  'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model.file',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.model.file',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058/content',
#             'method': 'GET',
#             'rel': 'content',
#             'type': 'application/octet-stream',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents/a4667441-94ef-43c3-8b2f-0819851d6058/content'}],
#  'modelId': '4c9e48c6-83fe-496c-9acd-692576f48b29',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:22:15.680Z',
#  'name': 'requirements.txt',
#  'role': 'Requirements',
#  'version': 2}

# %%
print(f'requirements.txt file\'s content ID: {myModelFile_2.get("id")}')

# %% [markdown]
# ### <font color='blue'>學員操作</font>

# %%
yourModel = model_repository.create_model(
    project = myProject,
    
    model = {
        'name':'Sklearn Gradient Boosting',
        'trainCodeType':'Python',
        'scoreCodeType':'Python'
    },
    modeler = 'student',
    description = 'Manually create model artifacts',
    
    function = "Classification",
    algorithm = 'Gradient Boosting',
    tool = f'Python {sys.version_info.major}',
    is_challenger = True,
    
    input_variables = input_variable_dict,
    output_variables = output_variable_dict,
    
    properties = {
        'gitlab-access-token': 'ynJH8ppLyiB_2L5sT2NY',
        'gitlab-project-id': '24272994',
        'author_email': 'fkl@sas.com',
        'author_name': 'fkl'  
    }
)


#
with open('./model_gb.pkl', 'wb') as file:
    pickle.dump(model_gb, file)

yourModelFile_1 = model_repository.add_model_content(
    model = yourModel,
    file = open('./model_gb.pkl', 'rb'),
    name = 'model_gb.pkl',
    role = 'Python pickle'
)


#
os.system('powershell.exe pip freeze > ./requirements_student.txt')
requirements_student_txt = open('./requirements_student.txt', 'r')       


yourModelFile_2 = model_repository.add_model_content(
    model = yourModel, 
    file = requirements_student_txt, 
    name = 'requirements_student.txt', 
    role = 'Requirements'
)

# 顯示模型的所有屬性
pprint(yourModel)
print(f'\nSklearn Gradient Boosting model ID: {myModel_1.get("id")}')
# Out:
# {'algorithm': 'Gradient Boosting',
#  'candidateChampion': False,
#  'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:20.210Z',
#  'description': 'Manually create model artifacts',
#  'folderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'function': 'Classification',
#  'globalTags': [],
#  'id': 'd238c041-cc45-4681-929a-4d3f1cb08f4e',
#  'immutable': False,
#  'indirectFolderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'inputVariables': [{'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'id': '5aece5f2-8cdd-49ee-b2a3-5e1531b74a76',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/5aece5f2-8cdd-49ee-b2a3-5e1531b74a76'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'name': 'LOAN',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'id': 'a822c89a-2680-49c7-8c5a-6c11a0576a05',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/a822c89a-2680-49c7-8c5a-6c11a0576a05'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'name': 'MORTDUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'id': 'fe6b3715-2106-4443-896f-a44490d73d70',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/fe6b3715-2106-4443-896f-a44490d73d70'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'name': 'VALUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'id': '92c1dc0c-ac3c-41eb-8ff2-737cb74b1552',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/92c1dc0c-ac3c-41eb-8ff2-737cb74b1552'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'name': 'YOJ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'id': 'd1e3489a-250a-4cb0-ad23-dfb505c0f2f0',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/d1e3489a-250a-4cb0-ad23-dfb505c0f2f0'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.336Z',
#                      'name': 'DEROG',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'id': '423feca7-2192-46b0-bf51-197131479087',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/423feca7-2192-46b0-bf51-197131479087'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'name': 'DELINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'id': '8e27de3c-9e3e-452a-ba0a-bf07785680a7',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/8e27de3c-9e3e-452a-ba0a-bf07785680a7'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'name': 'CLAGE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'id': '74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/74017a30-66ad-4cd7-9e8a-7ce8fc7ecb19'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'name': 'NINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'id': '2b9f539e-c6f0-425d-a08d-034d41bf911f',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/2b9f539e-c6f0-425d-a08d-034d41bf911f'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'name': 'CLNO',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'id': '48f31064-f6ff-40ca-855a-8f04cc5d8a57',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57'},
#                                {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/48f31064-f6ff-40ca-855a-8f04cc5d8a57'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                      'name': 'DEBTINC',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2}],
#  'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e'},
#            {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e',
#             'method': 'GET',
#             'rel': 'alternate',
#             'type': 'application/vnd.sas.models.model.summary',
#             'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e'},
#            {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e'},
#            {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e'},
#            {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/contents',
#             'method': 'GET',
#             'rel': 'contents',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/contents'}],
#  'location': '/Model Repositories/Public',
#  'modelVersionName': '1.0',
#  'modelVersions': [],
#  'modeler': 'student',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:22:20.210Z',
#  'name': 'Sklearn Gradient Boosting',
#  'outputVariables': [{'createdBy': 'modelDeveloper',
#                       'creationTimeStamp': '2021-03-05T06:22:20.337Z',
#                       'description': 'Put your comments here.',
#                       'id': 'c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e',
#                       'length': 2,
#                       'links': [{'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e',
#                                  'itemType': 'application/vnd.sas.models.variable',
#                                  'method': 'GET',
#                                  'rel': 'up',
#                                  'type': 'application/vnd.sas.collection',
#                                  'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables'},
#                                 {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e',
#                                  'method': 'GET',
#                                  'rel': 'self',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e'},
#                                 {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e',
#                                  'method': 'PUT',
#                                  'rel': 'update',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e'},
#                                 {'href': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e',
#                                  'method': 'DELETE',
#                                  'rel': 'delete',
#                                  'uri': '/modelRepository/models/d238c041-cc45-4681-929a-4d3f1cb08f4e/variables/c0561c8d-4b11-4ef0-a727-20a5f6e5bf7e'}],
#                       'modifiedBy': 'modelDeveloper',
#                       'modifiedTimeStamp': '2021-03-05T06:22:20.337Z',
#                       'name': 'BAD',
#                       'role': 'output',
#                       'type': 'binary',
#                       'version': 2}],
#  'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#  'projectName': 'hmeq_project',
#  'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#  'projectVersionName': 'Version 1',
#  'projectVersionNum': '1.0',
#  'properties': [{'name': 'gitlab-access-token',
#                  'type': 'string',
#                  'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                 {'name': 'gitlab-project-id',
#                  'type': 'string',
#                  'value': '24272994'},
#                 {'name': 'author_email',
#                  'type': 'string',
#                  'value': 'fkl@sas.com'},
#                 {'name': 'author_name', 'type': 'string', 'value': 'fkl'}],
#  'repositoryId': 'e85658ee-ee07-4e91-bd09-e50edb520097',
#  'retrainable': False,
#  'role': 'challenger',
#  'scoreCodeType': 'Python',
#  'suggestedChampion': False,
#  'tags': [],
#  'tool': 'Python 3',
#  'trainCodeType': 'Python',
#  'version': 2}
#
# Sklearn Gradient Boosting model ID: 4c9e48c6-83fe-496c-9acd-692576f48b29

# %% [markdown]
# ### <font color='red'>2-7. 簡易註冊模型 (Optional)</font>

# %%
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)

myModel_2 = register_model(
    project = myProject,
    name = "Sklearn Random Forest",
    model = model_rf,     
    input = data,
    record_packages = True # Capture Python packages registered in the environment
)

pprint(myModel_2)
print(f'\nSklearn Random Forest model ID: {myModel_2.get("id")}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.249.6.39'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.249.6.39'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'algorithm': 'Forest',
#  'candidateChampion': False,
#  'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:28.564Z',
#  'description': 'RandomForestClassifier()',
#  'folderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'function': 'classification',
#  'globalTags': [],
#  'id': '2c59d2f5-249a-474a-81dc-c34a2ef05234',
#  'immutable': False,
#  'indirectFolderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'links': [{'href': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234'},
#            {'href': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234',
#             'method': 'GET',
#             'rel': 'alternate',
#             'type': 'application/vnd.sas.models.model.summary',
#             'uri': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234'},
#            {'href': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234',
#             'method': 'PUT',
#             'rel': 'update',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234'},
#            {'href': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234'},
#            {'href': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234/contents',
#             'method': 'GET',
#             'rel': 'contents',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/2c59d2f5-249a-474a-81dc-c34a2ef05234/contents'}],
#  'location': '/Model Repositories/Public',
#  'modelVersionName': '1.0',
#  'modelVersions': [],
#  'modeler': 'modelDeveloper',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:22:28.564Z',
#  'name': 'Sklearn Random Forest',
#  'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#  'projectName': 'hmeq_project',
#  'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#  'projectVersionName': 'Version 1',
#  'projectVersionNum': '1.0',
#  'properties': [{'name': 'bootstrap', 'type': 'string', 'value': 'True'},
#                 {'name': 'ccp_alpha', 'type': 'string', 'value': '0.0'},
#                 {'name': 'class_weight', 'type': 'string', 'value': 'None'},
#                 {'name': 'criterion', 'type': 'string', 'value': 'gini'},
#                 {'name': 'max_depth', 'type': 'string', 'value': 'None'},
#                 {'name': 'max_features', 'type': 'string', 'value': 'auto'},
#                 {'name': 'max_leaf_nodes', 'type': 'string', 'value': 'None'},
#                 {'name': 'max_samples', 'type': 'string', 'value': 'None'},
#                 {'name': 'min_impurity_decrease',
#                  'type': 'string',
#                  'value': '0.0'},
#                 {'name': 'min_impurity_split',
#                  'type': 'string',
#                  'value': 'None'},
#                 {'name': 'min_samples_leaf', 'type': 'string', 'value': '1'},
#                 {'name': 'min_samples_split', 'type': 'string', 'value': '2'},
#                 {'name': 'min_weight_fraction_leaf',
#                  'type': 'string',
#                  'value': '0.0'},
#                 {'name': 'n_estimators', 'type': 'string', 'value': '100'},
#                 {'name': 'n_jobs', 'type': 'string', 'value': 'None'},
#                 {'name': 'oob_score', 'type': 'string', 'value': 'False'},
#                 {'name': 'random_state', 'type': 'string', 'value': 'None'},
#                 {'name': 'verbose', 'type': 'string', 'value': '0'},
#                 {'name': 'warm_start', 'type': 'string', 'value': 'False'},
#                 {'name': 'env_alabaster', 'type': 'string', 'value': '0.7.12'},
#                 {'name': 'env_anaconda-client',
#                  'type': 'string',
#                  'value': '1.7.2'},
#                 {'name': 'env_anaconda-navigator',
#                  'type': 'string',
#                  'value': '1.10.0'},
#                 {'name': 'env_anaconda-project',
#                  'type': 'string',
#                  'value': '0.8.3'},
#                 {'name': 'env_argh', 'type': 'string', 'value': '0.26.2'},
#                 {'name': 'env_astropy', 'type': 'string', 'value': '4.0.2'},
#                 {'name': 'env_async-generator',
#                  'type': 'string',
#                  'value': '1.10'},
#                 {'name': 'env_atomicwrites',
#                  'type': 'string',
#                  'value': '1.4.0'},
#                 {'name': 'env_backcall', 'type': 'string', 'value': '0.2.0'},
#                 {'name': 'env_backports.functools-lru-cache',
#                  'type': 'string',
#                  'value': '1.6.1'},
#                 {'name': 'env_backports.shutil-get-terminal-size',
#                  'type': 'string',
#                  'value': '1.0.0'},
#                 {'name': 'env_backports.tempfile',
#                  'type': 'string',
#                  'value': '1.0'},
#                 {'name': 'env_backports.weakref',
#                  'type': 'string',
#                  'value': '1.0.post1'},
#                 {'name': 'env_bkcharts', 'type': 'string', 'value': '0.2'},
#                 {'name': 'env_boto', 'type': 'string', 'value': '2.49.0'},
#                 {'name': 'env_Bottleneck', 'type': 'string', 'value': '1.3.2'},
#                 {'name': 'env_brotlipy', 'type': 'string', 'value': '0.7.0'},
#                 {'name': 'env_certifi', 'type': 'string', 'value': '2020.6.20'},
#                 {'name': 'env_chardet', 'type': 'string', 'value': '3.0.4'},
#                 {'name': 'env_click', 'type': 'string', 'value': '7.1.2'},
#                 {'name': 'env_clyent', 'type': 'string', 'value': '1.2.2'},
#                 {'name': 'env_comtypes', 'type': 'string', 'value': '1.1.7'},
#                 {'name': 'env_conda', 'type': 'string', 'value': '4.9.2'},
#                 {'name': 'env_conda-build',
#                  'type': 'string',
#                  'value': '3.20.5'},
#                 {'name': 'env_conda-verify',
#                  'type': 'string',
#                  'value': '3.4.2'},
#                 {'name': 'env_contextlib2',
#                  'type': 'string',
#                  'value': '0.6.0.post1'},
#                 {'name': 'env_cycler', 'type': 'string', 'value': '0.10.0'},
#                 {'name': 'env_cytoolz', 'type': 'string', 'value': '0.11.0'},
#                 {'name': 'env_decorator', 'type': 'string', 'value': '4.4.2'},
#                 {'name': 'env_defusedxml', 'type': 'string', 'value': '0.6.0'},
#                 {'name': 'env_docutils', 'type': 'string', 'value': '0.16'},
#                 {'name': 'env_entrypoints', 'type': 'string', 'value': '0.3'},
#                 {'name': 'env_et-xmlfile', 'type': 'string', 'value': '1.0.1'},
#                 {'name': 'env_fastcache', 'type': 'string', 'value': '1.1.0'},
#                 {'name': 'env_featuretools',
#                  'type': 'string',
#                  'value': '0.23.0'},
#                 {'name': 'env_filelock', 'type': 'string', 'value': '3.0.12'},
#                 {'name': 'env_Flask', 'type': 'string', 'value': '1.1.2'},
#                 {'name': 'env_future', 'type': 'string', 'value': '0.18.2'},
#                 {'name': 'env_glob2', 'type': 'string', 'value': '0.7'},
#                 {'name': 'env_graphviz', 'type': 'string', 'value': '0.16'},
#                 {'name': 'env_h5py', 'type': 'string', 'value': '2.10.0'},
#                 {'name': 'env_HeapDict', 'type': 'string', 'value': '1.0.1'},
#                 {'name': 'env_imagesize', 'type': 'string', 'value': '1.2.0'},
#                 {'name': 'env_ipython-genutils',
#                  'type': 'string',
#                  'value': '0.2.0'},
#                 {'name': 'env_itsdangerous',
#                  'type': 'string',
#                  'value': '1.1.0'},
#                 {'name': 'env_jdcal', 'type': 'string', 'value': '1.4.1'},
#                 {'name': 'env_Jinja2', 'type': 'string', 'value': '2.11.2'},
#                 {'name': 'env_json5', 'type': 'string', 'value': '0.9.5'},
#                 {'name': 'env_jupyter', 'type': 'string', 'value': '1.0.0'},
#                 {'name': 'env_jupyter-core',
#                  'type': 'string',
#                  'value': '4.6.3'},
#                 {'name': 'env_jupyterlab', 'type': 'string', 'value': '2.2.6'},
#                 {'name': 'env_lazy-object-proxy',
#                  'type': 'string',
#                  'value': '1.4.3'},
#                 {'name': 'env_libarchive-c', 'type': 'string', 'value': '2.9'},
#                 {'name': 'env_llvmlite', 'type': 'string', 'value': '0.34.0'},
#                 {'name': 'env_locket', 'type': 'string', 'value': '0.2.0'},
#                 {'name': 'env_MarkupSafe', 'type': 'string', 'value': '1.1.1'},
#                 {'name': 'env_mccabe', 'type': 'string', 'value': '0.6.1'},
#                 {'name': 'env_menuinst', 'type': 'string', 'value': '1.4.16'},
#                 {'name': 'env_mistune', 'type': 'string', 'value': '0.8.4'},
#                 {'name': 'env_mkl-fft', 'type': 'string', 'value': '1.2.0'},
#                 {'name': 'env_mkl-random', 'type': 'string', 'value': '1.1.1'},
#                 {'name': 'env_mkl-service', 'type': 'string', 'value': '2.3.0'},
#                 {'name': 'env_mock', 'type': 'string', 'value': '4.0.2'},
#                 {'name': 'env_mpmath', 'type': 'string', 'value': '1.1.0'},
#                 {'name': 'env_msgpack', 'type': 'string', 'value': '1.0.0'},
#                 {'name': 'env_multipledispatch',
#                  'type': 'string',
#                  'value': '0.6.0'},
#                 {'name': 'env_navigator-updater',
#                  'type': 'string',
#                  'value': '0.2.1'},
#                 {'name': 'env_nose', 'type': 'string', 'value': '1.3.7'},
#                 {'name': 'env_numba', 'type': 'string', 'value': '0.51.2'},
#                 {'name': 'env_numexpr', 'type': 'string', 'value': '2.7.1'},
#                 {'name': 'env_olefile', 'type': 'string', 'value': '0.46'},
#                 {'name': 'env_packaging', 'type': 'string', 'value': '20.4'},
#                 {'name': 'env_parso', 'type': 'string', 'value': '0.7.0'},
#                 {'name': 'env_partd', 'type': 'string', 'value': '1.1.0'},
#                 {'name': 'env_pathlib2', 'type': 'string', 'value': '2.3.5'},
#                 {'name': 'env_pathtools', 'type': 'string', 'value': '0.1.2'},
#                 {'name': 'env_patsy', 'type': 'string', 'value': '0.5.1'},
#                 {'name': 'env_pep8', 'type': 'string', 'value': '1.7.1'},
#                 {'name': 'env_pexpect', 'type': 'string', 'value': '4.8.0'},
#                 {'name': 'env_pickleshare', 'type': 'string', 'value': '0.7.5'},
#                 {'name': 'env_pip', 'type': 'string', 'value': '20.2.4'},
#                 {'name': 'env_pkginfo', 'type': 'string', 'value': '1.6.1'},
#                 {'name': 'env_pluggy', 'type': 'string', 'value': '0.13.1'},
#                 {'name': 'env_ply', 'type': 'string', 'value': '3.11'},
#                 {'name': 'env_prometheus-client',
#                  'type': 'string',
#                  'value': '0.8.0'},
#                 {'name': 'env_psycopg2', 'type': 'string', 'value': '2.8.6'},
#                 {'name': 'env_py-postgresql',
#                  'type': 'string',
#                  'value': '1.2.2'},
#                 {'name': 'env_pycodestyle', 'type': 'string', 'value': '2.6.0'},
#                 {'name': 'env_pycosat', 'type': 'string', 'value': '0.6.3'},
#                 {'name': 'env_pycurl', 'type': 'string', 'value': '7.43.0.6'},
#                 {'name': 'env_pyflakes', 'type': 'string', 'value': '2.2.0'},
#                 {'name': 'env_pyodbc',
#                  'type': 'string',
#                  'value': '=4.0.0-unsupported'},
#                 {'name': 'env_pyparsing', 'type': 'string', 'value': '2.4.7'},
#                 {'name': 'env_pyreadline', 'type': 'string', 'value': '2.1'},
#                 {'name': 'env_PySocks', 'type': 'string', 'value': '1.7.1'},
#                 {'name': 'env_pytest', 'type': 'string', 'value': '0.0.0'},
#                 {'name': 'env_python-dateutil',
#                  'type': 'string',
#                  'value': '2.8.1'},
#                 {'name': 'env_python-gitlab',
#                  'type': 'string',
#                  'value': '2.6.0'},
#                 {'name': 'env_pytz', 'type': 'string', 'value': '2020.1'},
#                 {'name': 'env_pywin32', 'type': 'string', 'value': '227'},
#                 {'name': 'env_pywin32-ctypes',
#                  'type': 'string',
#                  'value': '0.2.0'},
#                 {'name': 'env_pywinpty', 'type': 'string', 'value': '0.5.7'},
#                 {'name': 'env_PyYAML', 'type': 'string', 'value': '5.3.1'},
#                 {'name': 'env_pyzmq', 'type': 'string', 'value': '19.0.2'},
#                 {'name': 'env_QDarkStyle', 'type': 'string', 'value': '2.8.1'},
#                 {'name': 'env_QtPy', 'type': 'string', 'value': '1.9.0'},
#                 {'name': 'env_requests-toolbelt',
#                  'type': 'string',
#                  'value': '0.9.1'},
#                 {'name': 'env_Rtree', 'type': 'string', 'value': '0.9.4'},
#                 {'name': 'env_ruamel-yaml',
#                  'type': 'string',
#                  'value': '0.15.87'},
#                 {'name': 'env_sasctl', 'type': 'string', 'value': '1.5.4'},
#                 {'name': 'env_scikit-image',
#                  'type': 'string',
#                  'value': '0.17.2'},
#                 {'name': 'env_Send2Trash', 'type': 'string', 'value': '1.5.0'},
#                 {'name': 'env_setuptools',
#                  'type': 'string',
#                  'value': '50.3.1.post20201107'},
#                 {'name': 'env_simplegeneric',
#                  'type': 'string',
#                  'value': '0.8.1'},
#                 {'name': 'env_sip', 'type': 'string', 'value': '4.19.13'},
#                 {'name': 'env_sklearn', 'type': 'string', 'value': '0.0'},
#                 {'name': 'env_snowballstemmer',
#                  'type': 'string',
#                  'value': '2.0.0'},
#                 {'name': 'env_sortedcollections',
#                  'type': 'string',
#                  'value': '1.2.1'},
#                 {'name': 'env_sortedcontainers',
#                  'type': 'string',
#                  'value': '2.2.2'},
#                 {'name': 'env_soupsieve', 'type': 'string', 'value': '2.0.1'},
#                 {'name': 'env_sphinxcontrib-applehelp',
#                  'type': 'string',
#                  'value': '1.0.2'},
#                 {'name': 'env_sphinxcontrib-devhelp',
#                  'type': 'string',
#                  'value': '1.0.2'},
#                 {'name': 'env_sphinxcontrib-htmlhelp',
#                  'type': 'string',
#                  'value': '1.0.3'},
#                 {'name': 'env_sphinxcontrib-jsmath',
#                  'type': 'string',
#                  'value': '1.0.1'},
#                 {'name': 'env_sphinxcontrib-qthelp',
#                  'type': 'string',
#                  'value': '1.0.3'},
#                 {'name': 'env_sphinxcontrib-serializinghtml',
#                  'type': 'string',
#                  'value': '1.1.4'},
#                 {'name': 'env_statsmodels',
#                  'type': 'string',
#                  'value': '0.12.0'},
#                 {'name': 'env_swat', 'type': 'string', 'value': '1.8.1'},
#                 {'name': 'env_tables', 'type': 'string', 'value': '3.6.1'},
#                 {'name': 'env_terminado', 'type': 'string', 'value': '0.9.1'},
#                 {'name': 'env_testpath', 'type': 'string', 'value': '0.4.4'},
#                 {'name': 'env_tifffile',
#                  'type': 'string',
#                  'value': '2020.10.1'},
#                 {'name': 'env_tornado', 'type': 'string', 'value': '6.0.4'},
#                 {'name': 'env_unicodecsv', 'type': 'string', 'value': '0.14.1'},
#                 {'name': 'env_webencodings',
#                  'type': 'string',
#                  'value': '0.5.1'},
#                 {'name': 'env_Werkzeug', 'type': 'string', 'value': '1.0.1'},
#                 {'name': 'env_wheel', 'type': 'string', 'value': '0.35.1'},
#                 {'name': 'env_widgetsnbextension',
#                  'type': 'string',
#                  'value': '3.5.1'},
#                 {'name': 'env_win-inet-pton',
#                  'type': 'string',
#                  'value': '1.1.0'},
#                 {'name': 'env_win-unicode-console',
#                  'type': 'string',
#                  'value': '0.5'},
#                 {'name': 'env_wincertstore', 'type': 'string', 'value': '0.2'},
#                 {'name': 'env_wrapt', 'type': 'string', 'value': '1.11.2'},
#                 {'name': 'env_xgboost', 'type': 'string', 'value': '1.3.3'},
#                 {'name': 'env_xlrd', 'type': 'string', 'value': '1.2.0'},
#                 {'name': 'env_xlwings', 'type': 'string', 'value': '0.20.8'},
#                 {'name': 'env_xlwt', 'type': 'string', 'value': '1.3.0'},
#                 {'name': 'env_xmltodict', 'type': 'string', 'value': '0.12.0'},
#                 {'name': 'env_zict', 'type': 'string', 'value': '2.0.0'},
#                 {'name': 'env_zope.event', 'type': 'string', 'value': '4.5.0'}],
#  'repositoryId': 'e85658ee-ee07-4e91-bd09-e50edb520097',
#  'retrainable': False,
#  'role': 'plain',
#  'scoreCodeType': 'ds2MultiType',
#  'suggestedChampion': False,
#  'tags': [],
#  'tool': 'Python 3.8',
#  'trainCodeType': 'Python',
#  'version': 2}
#
# Sklearn Random Forest model ID: 2c59d2f5-249a-474a-81dc-c34a2ef05234

# %% [markdown]
# # 3. 模型版本控制
# [Top](#Table-of-Content)

# %% [markdown]
# ### 3-1. 新增模型的版本號碼

# %%
desired_model_id = myModel_1.get('id')

desired_model = model_repository.get_model(item = desired_model_id)

desired_model_new = model_repository.create_model_version(model = desired_model, minor = False)

# %% [markdown]
# ### 3-2. 更新模型的屬性

# %%
print(f'Target Variable: \033[94m{desired_model_new.get("targetVariable")}\033[0;0m')
print(f'Target Event Value: \033[94m{desired_model_new.get("targetEventValue")}\033[0;0m')
print(f'Modeler: \033[94m{desired_model_new.get("modeler")}\033[0;0m')
# Out:
# Target Variable: BADDDD
# Target Event Value: None
# Modeler: frank

# %%
desired_model_new['targetVariable'] = 'BAD'
desired_model_new['targetEventValue'] = 'bad'
desired_model_new['modeler'] = 'frank lin'

model_repository.update_model(desired_model_new)

print(f'Target Variable: \033[94m{desired_model_new.get("targetVariable")}\033[0;0m')
print(f'Target Event Value: \033[94m{desired_model_new.get("targetEventValue")}\033[0;0m')
print(f'Modeler: \033[94m{desired_model_new.get("modeler")}\033[0;0m')
# Out:
# Target Variable: BAD
# Target Event Value: bad
# Modeler: frank lin

# %% [markdown]
# ### 3-3. 確認模型的最新版本和屬性

# %%
pprint(desired_model_new)
# Out:
# {'algorithm': 'Decision Tree',
#  'candidateChampion': False,
#  'createdBy': 'modelDeveloper',
#  'creationTimeStamp': '2021-03-05T06:22:07.277Z',
#  'description': 'Manually create model artifacts',
#  'folderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'function': 'Classification',
#  'globalTags': [],
#  'id': '4c9e48c6-83fe-496c-9acd-692576f48b29',
#  'immutable': False,
#  'indirectFolderId': 'dc52a9ea-8353-4143-b0bf-e89f3d9ec23a',
#  'inputVariables': [{'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'd7578afd-1619-4731-af8a-4182b94c97f0',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d7578afd-1619-4731-af8a-4182b94c97f0'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'CLAGE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/368cc07c-b0ab-4916-bc17-66157c3f6e96'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'CLNO',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/6ac18bff-bc5f-4e04-8809-8534bca2465d'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DEBTINC',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '639f61dc-f720-4e71-b395-5965353cfa30',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/639f61dc-f720-4e71-b395-5965353cfa30'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DELINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/ed9dca4e-1906-4779-a2d8-6b03397c6df9'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'DEROG',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'db133fab-9f61-407e-b9f1-d7938d94bf84',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/db133fab-9f61-407e-b9f1-d7938d94bf84'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'LOAN',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/4e83af74-0c7c-4559-b9a1-7297a2ff4ad4'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'MORTDUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/aeae2cbb-9dc1-4b15-8a6c-8d83cb6288e5'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'NINQ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': '631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/631131e7-9e6f-44d0-a1a5-0e795cd5f5ce'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'VALUE',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2},
#                     {'createdBy': 'modelDeveloper',
#                      'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'id': 'd142dea5-5fc2-44e3-a748-9c6570d59603',
#                      'length': 8,
#                      'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'itemType': 'application/vnd.sas.models.variable',
#                                 'method': 'GET',
#                                 'rel': 'up',
#                                 'type': 'application/vnd.sas.collection',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'GET',
#                                 'rel': 'self',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'PUT',
#                                 'rel': 'update',
#                                 'type': 'application/vnd.sas.models.variable',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'},
#                                {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603',
#                                 'method': 'DELETE',
#                                 'rel': 'delete',
#                                 'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/d142dea5-5fc2-44e3-a748-9c6570d59603'}],
#                      'modifiedBy': 'modelDeveloper',
#                      'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                      'name': 'YOJ',
#                      'role': 'input',
#                      'type': 'decimal',
#                      'version': 2}],
#  'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'GET',
#             'rel': 'self',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'GET',
#             'rel': 'alternate',
#             'type': 'application/vnd.sas.models.model.summary',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/code',
#             'method': 'GET',
#             'rel': 'scoreCode',
#             'type': 'text/plain',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/code'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents',
#             'itemType': 'application/vnd.sas.models.model.content.summary',
#             'method': 'GET',
#             'rel': 'contents',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/contents'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'PUT',
#             'rel': 'update',
#             'responseType': 'application/vnd.sas.models.model',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'DELETE',
#             'rel': 'delete',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions',
#             'method': 'GET',
#             'rel': 'modelVersions',
#             'responseItemType': 'application/vnd.sas.models.version',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions',
#             'method': 'POST',
#             'rel': 'addModelVersion',
#             'type': 'application/vnd.sas.models.model.version',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions'},
#            {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables',
#             'itemType': 'application/vnd.sas.models.variable',
#             'method': 'GET',
#             'rel': 'variables',
#             'type': 'application/vnd.sas.collection',
#             'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion?modelId=4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'POST',
#             'rel': 'setAsChampion',
#             'responseType': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/champion?modelId=4c9e48c6-83fe-496c-9acd-692576f48b29'},
#            {'href': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers?modelId=4c9e48c6-83fe-496c-9acd-692576f48b29',
#             'method': 'DELETE',
#             'rel': 'unsetAsChallenger',
#             'type': 'application/vnd.sas.models.model',
#             'uri': '/modelRepository/projects/8373e5fc-ca71-4841-af2e-f77bdeca6ea5/challengers?modelId=4c9e48c6-83fe-496c-9acd-692576f48b29'}],
#  'location': '/Model Repositories/Public',
#  'modelVersionName': '4.0',
#  'modelVersions': [{'algorithm': 'Decision Tree',
#                     'candidateChampion': False,
#                     'createdBy': 'modelDeveloper',
#                     'creationTimeStamp': '2021-03-05T06:26:25.490Z',
#                     'description': 'Manually create model artifacts',
#                     'function': 'Classification',
#                     'globalTags': [],
#                     'id': '76670cd7-c125-49a8-a5a9-dab4e5e0ae71',
#                     'immutable': True,
#                     'inputVariables': [{'length': 8,
#                                         'name': 'CLAGE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'CLNO',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEBTINC',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DELINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEROG',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'LOAN',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'MORTDUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'NINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'VALUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'YOJ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2}],
#                     'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions',
#                                'itemType': 'application/vnd.sas.models.model',
#                                'method': 'GET',
#                                'rel': 'up',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/76670cd7-c125-49a8-a5a9-dab4e5e0ae71',
#                                'method': 'GET',
#                                'rel': 'self',
#                                'type': 'application/vnd.sas.models.model',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/76670cd7-c125-49a8-a5a9-dab4e5e0ae71'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/76670cd7-c125-49a8-a5a9-dab4e5e0ae71',
#                                'itemType': 'application/vnd.sas.models.model.content',
#                                'method': 'GET',
#                                'rel': 'contents',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/76670cd7-c125-49a8-a5a9-dab4e5e0ae71/contents'}],
#                     'modelCreatedBy': 'modelDeveloper',
#                     'modelCreationTimeStamp': '2021-03-05T06:22:07.277Z',
#                     'modelLastModifiedBy': 'modelDeveloper',
#                     'modelLastModifiedTimeStamp': '2021-03-05T06:22:15.681Z',
#                     'modelVersionName': '1.0',
#                     'modeler': 'frank',
#                     'modifiedBy': 'modelDeveloper',
#                     'modifiedTimeStamp': '2021-03-05T06:26:25.490Z',
#                     'name': 'Sklearn Decision Tree',
#                     'outputVariables': [{'description': 'Put your comments '
#                                                         'here.',
#                                          'length': 2,
#                                          'name': 'BAD',
#                                          'role': 'output',
#                                          'type': 'binary',
#                                          'version': 2}],
#                     'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#                     'projectName': 'hmeq_project',
#                     'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#                     'projectVersionName': 'Version 1',
#                     'projectVersionNum': '1.0',
#                     'properties': [{'name': 'gitlab-access-token',
#                                     'type': 'string',
#                                     'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                                    {'name': 'gitlab-project-id',
#                                     'type': 'string',
#                                     'value': '24272994'},
#                                    {'name': 'author_email',
#                                     'type': 'string',
#                                     'value': 'fkl@sas.com'},
#                                    {'name': 'author_name',
#                                     'type': 'string',
#                                     'value': 'fkl'}],
#                     'retrainable': False,
#                     'role': 'challenger',
#                     'scoreCodeType': 'Python',
#                     'suggestedChampion': False,
#                     'tags': [],
#                     'tool': 'Python 3',
#                     'trainCodeType': 'Python',
#                     'version': 2},
#                    {'algorithm': 'Decision Tree',
#                     'candidateChampion': False,
#                     'createdBy': 'modelDeveloper',
#                     'creationTimeStamp': '2021-03-05T06:26:47.480Z',
#                     'description': 'Manually create model artifacts',
#                     'function': 'Classification',
#                     'globalTags': [],
#                     'id': '006efdf3-6791-445f-aca5-e3606276fa91',
#                     'immutable': True,
#                     'inputVariables': [{'length': 8,
#                                         'name': 'CLAGE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'CLNO',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEBTINC',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DELINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEROG',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'LOAN',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'MORTDUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'NINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'VALUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'YOJ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2}],
#                     'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions',
#                                'itemType': 'application/vnd.sas.models.model',
#                                'method': 'GET',
#                                'rel': 'up',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/006efdf3-6791-445f-aca5-e3606276fa91',
#                                'method': 'GET',
#                                'rel': 'self',
#                                'type': 'application/vnd.sas.models.model',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/006efdf3-6791-445f-aca5-e3606276fa91'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/006efdf3-6791-445f-aca5-e3606276fa91',
#                                'itemType': 'application/vnd.sas.models.model.content',
#                                'method': 'GET',
#                                'rel': 'contents',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/006efdf3-6791-445f-aca5-e3606276fa91/contents'}],
#                     'modelCreatedBy': 'modelDeveloper',
#                     'modelCreationTimeStamp': '2021-03-05T06:22:07.277Z',
#                     'modelLastModifiedBy': 'modelDeveloper',
#                     'modelLastModifiedTimeStamp': '2021-03-05T06:26:25.593Z',
#                     'modelVersionName': '2.0',
#                     'modeler': 'frank',
#                     'modifiedBy': 'modelDeveloper',
#                     'modifiedTimeStamp': '2021-03-05T06:26:47.480Z',
#                     'name': 'Sklearn Decision Tree',
#                     'outputVariables': [{'description': 'Put your comments '
#                                                         'here.',
#                                          'length': 2,
#                                          'name': 'BAD',
#                                          'role': 'output',
#                                          'type': 'binary',
#                                          'version': 2}],
#                     'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#                     'projectName': 'hmeq_project',
#                     'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#                     'projectVersionName': 'Version 1',
#                     'projectVersionNum': '1.0',
#                     'properties': [{'name': 'gitlab-access-token',
#                                     'type': 'string',
#                                     'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                                    {'name': 'gitlab-project-id',
#                                     'type': 'string',
#                                     'value': '24272994'},
#                                    {'name': 'author_email',
#                                     'type': 'string',
#                                     'value': 'fkl@sas.com'},
#                                    {'name': 'author_name',
#                                     'type': 'string',
#                                     'value': 'fkl'}],
#                     'retrainable': False,
#                     'role': 'challenger',
#                     'scoreCodeType': 'Python',
#                     'suggestedChampion': False,
#                     'tags': [],
#                     'tool': 'Python 3',
#                     'trainCodeType': 'Python',
#                     'version': 2},
#                    {'algorithm': 'Decision Tree',
#                     'candidateChampion': False,
#                     'createdBy': 'modelDeveloper',
#                     'creationTimeStamp': '2021-03-05T06:33:41.412Z',
#                     'description': 'Manually create model artifacts',
#                     'function': 'Classification',
#                     'globalTags': [],
#                     'id': '55ad7403-a1d8-4910-88b9-db88a6e47775',
#                     'immutable': True,
#                     'inputVariables': [{'length': 8,
#                                         'name': 'CLAGE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'CLNO',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEBTINC',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DELINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'DEROG',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'LOAN',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'MORTDUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'NINQ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'VALUE',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2},
#                                        {'length': 8,
#                                         'name': 'YOJ',
#                                         'role': 'input',
#                                         'type': 'decimal',
#                                         'version': 2}],
#                     'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions',
#                                'itemType': 'application/vnd.sas.models.model',
#                                'method': 'GET',
#                                'rel': 'up',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/55ad7403-a1d8-4910-88b9-db88a6e47775',
#                                'method': 'GET',
#                                'rel': 'self',
#                                'type': 'application/vnd.sas.models.model',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/55ad7403-a1d8-4910-88b9-db88a6e47775'},
#                               {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/55ad7403-a1d8-4910-88b9-db88a6e47775',
#                                'itemType': 'application/vnd.sas.models.model.content',
#                                'method': 'GET',
#                                'rel': 'contents',
#                                'type': 'application/vnd.sas.collection',
#                                'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/modelVersions/55ad7403-a1d8-4910-88b9-db88a6e47775/contents'}],
#                     'modelCreatedBy': 'modelDeveloper',
#                     'modelCreationTimeStamp': '2021-03-05T06:22:07.277Z',
#                     'modelLastModifiedBy': 'modelDeveloper',
#                     'modelLastModifiedTimeStamp': '2021-03-05T06:27:08.214Z',
#                     'modelVersionName': '3.0',
#                     'modeler': 'frank',
#                     'modifiedBy': 'modelDeveloper',
#                     'modifiedTimeStamp': '2021-03-05T06:33:41.412Z',
#                     'name': 'Sklearn Decision Tree',
#                     'outputVariables': [{'description': 'Put your comments '
#                                                         'here.',
#                                          'length': 2,
#                                          'name': 'BAD',
#                                          'role': 'output',
#                                          'type': 'binary',
#                                          'version': 2}],
#                     'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#                     'projectName': 'hmeq_project',
#                     'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#                     'projectVersionName': 'Version 1',
#                     'projectVersionNum': '1.0',
#                     'properties': [{'name': 'gitlab-access-token',
#                                     'type': 'string',
#                                     'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                                    {'name': 'gitlab-project-id',
#                                     'type': 'string',
#                                     'value': '24272994'},
#                                    {'name': 'author_email',
#                                     'type': 'string',
#                                     'value': 'fkl@sas.com'},
#                                    {'name': 'author_name',
#                                     'type': 'string',
#                                     'value': 'fkl'}],
#                     'retrainable': False,
#                     'role': 'challenger',
#                     'scoreCodeType': 'Python',
#                     'suggestedChampion': False,
#                     'tags': [],
#                     'targetVariable': 'BADDDD',
#                     'tool': 'Python 3',
#                     'trainCodeType': 'Python',
#                     'version': 2}],
#  'modeler': 'frank lin',
#  'modifiedBy': 'modelDeveloper',
#  'modifiedTimeStamp': '2021-03-05T06:33:41.502Z',
#  'name': 'Sklearn Decision Tree',
#  'outputVariables': [{'createdBy': 'modelDeveloper',
#                       'creationTimeStamp': '2021-03-05T06:22:07.388Z',
#                       'description': 'Put your comments here.',
#                       'id': 'f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                       'length': 2,
#                       'links': [{'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'itemType': 'application/vnd.sas.models.variable',
#                                  'method': 'GET',
#                                  'rel': 'up',
#                                  'type': 'application/vnd.sas.collection',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'GET',
#                                  'rel': 'self',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'PUT',
#                                  'rel': 'update',
#                                  'type': 'application/vnd.sas.models.variable',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'},
#                                 {'href': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd',
#                                  'method': 'DELETE',
#                                  'rel': 'delete',
#                                  'uri': '/modelRepository/models/4c9e48c6-83fe-496c-9acd-692576f48b29/variables/f67945e3-b8dc-4c7a-b6a3-7427d21bfdcd'}],
#                       'modifiedBy': 'modelDeveloper',
#                       'modifiedTimeStamp': '2021-03-05T06:22:07.388Z',
#                       'name': 'BAD',
#                       'role': 'output',
#                       'type': 'binary',
#                       'version': 2}],
#  'projectId': '8373e5fc-ca71-4841-af2e-f77bdeca6ea5',
#  'projectName': 'hmeq_project',
#  'projectVersionId': '4b871ba3-6621-43d4-bede-0ab6291c14cd',
#  'projectVersionName': 'Version 1',
#  'projectVersionNum': '1.0',
#  'properties': [{'name': 'gitlab-access-token',
#                  'type': 'string',
#                  'value': 'ynJH8ppLyiB_2L5sT2NY'},
#                 {'name': 'gitlab-project-id',
#                  'type': 'string',
#                  'value': '24272994'},
#                 {'name': 'author_email',
#                  'type': 'string',
#                  'value': 'fkl@sas.com'},
#                 {'name': 'author_name', 'type': 'string', 'value': 'fkl'}],
#  'repositoryId': 'e85658ee-ee07-4e91-bd09-e50edb520097',
#  'retrainable': False,
#  'role': 'challenger',
#  'scoreCodeType': 'Python',
#  'suggestedChampion': False,
#  'tags': [],
#  'targetEventValue': 'bad',
#  'targetVariable': 'BAD',
#  'tool': 'Python 3',
#  'trainCodeType': 'Python',
#  'version': 2}

# %% [markdown]
# ---
